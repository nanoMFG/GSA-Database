# %%
import os

from sqlalchemy import and_, or_
import pandas as pd
pd.set_option("display.max_rows", None)

os.chdir(os.getcwd() + '/../src')
from grdb.config import Config
from grdb.database import dal as test_db  # test dal
from grdb.database import Base            # test base

# %%
# Testing Configuration and dal initialization
config_prefix = "TEST_DATABASE"
config_suffix = "_ADMIN" 
conf = Config(prefix=config_prefix, suffix=config_suffix, debug=True, try_secrets=False)
test_db.init_db(conf, privileges={"read": True, "write": True, "validate": True})

# %%
# 0) Stand up fresh empty test db
sess = test_db.Session()
sess.close()

Base.metadata.drop_all(test_db.engine)
Base.metadata.create_all(test_db.engine)

# %%
# Populating Author table
os.chdir(os.getcwd() + '/../test')
from database.factories import ExperimentFactory
from grdb.database.models import SemFile
x = SemFile(experiment_id=10,filename="filename.xyz",url="dhos@dlaf.com")
sess.add(x)
sess.flush()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/gresq38/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/envs/gresq38/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     607     def do_execute(self, cursor, statement, parameters, context=None):
# --> 608         cursor.execute(statement, parameters)
#     609
#
# ~/opt/anaconda3/envs/gresq38/lib/python3.9/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ...
